-- %%
drop table if exists dog_warehouse.default.dog_allergy;

-- %%
create table dog_warehouse.default.dog_allergy (
  dog_name string,
  description string,
  life_max integer,
  life_min integer,
  male_weight_max integer,
  male_weight_min integer,
  female_weight_max integer,
  female_weight_min integer
) using delta
;
